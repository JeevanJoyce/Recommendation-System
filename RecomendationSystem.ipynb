# %%
# !pip install -qq convokit
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.2/183.2 kB 4.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 6.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.5/235.5 kB 9.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 677.1/677.1 kB 12.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.4/300.4 kB 17.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.4/175.4 kB 12.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 4.8 MB/s eta 0:00:00
#   Building wheel for convokit (pyproject.toml) ... done
#   Building wheel for emoji (setup.py) ... done

# %%
# !pip install -qq scikit-surprise
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 772.0/772.0 kB 6.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for scikit-surprise (setup.py) ... done

# %%
import pandas as pd
import numpy as np
from surprise import Dataset, Reader, SVD
from surprise.model_selection import train_test_split
from surprise import accuracy
import convokit

# %%
# Load the Dataset
# Cornell Movie Dialogs Corpus
corpus = convokit.Corpus(filename=convokit.download("movie-corpus"))
# Out:
# Downloading movie-corpus to /root/.convokit/downloads/movie-corpus
# Downloading movie-corpus from http://zissou.infosci.cornell.edu/convokit/datasets/movie-corpus/movie-corpus.zip (40.9MB)... Done
# No configuration file found at /root/.convokit/config.yml; writing with contents:
# # Default Backend Parameters
# db_host: localhost:27017
# data_directory: ~/.convokit/saved-corpora
# default_backend: mem

# %%
# Display basic statistics
print("Number of conversations:", len(corpus.conversations))
print("Number of users:", len(corpus.speakers))
print("Number of utterances:", len(corpus.utterances))
# Out:
# Number of conversations: 83097
# Number of users: 9035
# Number of utterances: 304713

# %%
# Display information about conversations
for convo_id in corpus.get_conversation_ids():
    convo = corpus.get_conversation(convo_id)
    print("Conversation ID:", convo_id)
    print("Metadata:", convo.meta)
    print("Number of utterances in conversation:", len(convo.get_utterance_ids()))
    print()
# Out:
# Streaming output truncated to the last 5000 lines.
# Conversation ID: L329547
# Metadata: ConvoKitMeta({'movie_idx': 'm109', 'movie_name': 'juno', 'release_year': '2007', 'rating': '7.90', 'votes': '152436', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L329542
# Metadata: ConvoKitMeta({'movie_idx': 'm109', 'movie_name': 'juno', 'release_year': '2007', 'rating': '7.90', 'votes': '152436', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L329429
# Metadata: ConvoKitMeta({'movie_idx': 'm109', 'movie_name': 'juno', 'release_year': '2007', 'rating': '7.90', 'votes': '152436', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L329420
# Metadata: ConvoKitMeta({'movie_idx': 'm109', 'movie_name': 'juno', 'release_year': '2007', 'rating': '7.90', 'votes': '152436', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 9
#
# Conversation ID: L330019
# Metadata: ConvoKitMeta({'movie_idx': 'm109', 'movie_name': 'juno', 'release_year': '2007', 'rating': '7.90', 'votes': '152436', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L330017
# Metadata: ConvoKitMeta({'movie_idx': 'm109', 'movie_name': 'juno', 'release_year': '2007', 'rating': '7.90', 'votes': '152436', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L329898
# Metadata: ConvoKitMeta({'movie_idx': 'm109', 'movie_name': 'juno', 'release_year': '2007', 'rating': '7.90', 'votes': '152436', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L329891
# Metadata: ConvoKitMeta({'movie_idx': 'm109', 'movie_name': 'juno', 'release_year': '2007', 'rating': '7.90', 'votes': '152436', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L329884
# Metadata: ConvoKitMeta({'movie_idx': 'm109', 'movie_name': 'juno', 'release_year': '2007', 'rating': '7.90', 'votes': '152436', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L329881
# Metadata: ConvoKitMeta({'movie_idx': 'm109', 'movie_name': 'juno', 'release_year': '2007', 'rating': '7.90', 'votes': '152436', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L329800
# Metadata: ConvoKitMeta({'movie_idx': 'm109', 'movie_name': 'juno', 'release_year': '2007', 'rating': '7.90', 'votes': '152436', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L329795
# Metadata: ConvoKitMeta({'movie_idx': 'm109', 'movie_name': 'juno', 'release_year': '2007', 'rating': '7.90', 'votes': '152436', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L329791
# Metadata: ConvoKitMeta({'movie_idx': 'm109', 'movie_name': 'juno', 'release_year': '2007', 'rating': '7.90', 'votes': '152436', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L329782
# Metadata: ConvoKitMeta({'movie_idx': 'm109', 'movie_name': 'juno', 'release_year': '2007', 'rating': '7.90', 'votes': '152436', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L329780
# Metadata: ConvoKitMeta({'movie_idx': 'm109', 'movie_name': 'juno', 'release_year': '2007', 'rating': '7.90', 'votes': '152436', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L329778
# Metadata: ConvoKitMeta({'movie_idx': 'm109', 'movie_name': 'juno', 'release_year': '2007', 'rating': '7.90', 'votes': '152436', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L329774
# Metadata: ConvoKitMeta({'movie_idx': 'm109', 'movie_name': 'juno', 'release_year': '2007', 'rating': '7.90', 'votes': '152436', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L329645
# Metadata: ConvoKitMeta({'movie_idx': 'm109', 'movie_name': 'juno', 'release_year': '2007', 'rating': '7.90', 'votes': '152436', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L329641
# Metadata: ConvoKitMeta({'movie_idx': 'm109', 'movie_name': 'juno', 'release_year': '2007', 'rating': '7.90', 'votes': '152436', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L329587
# Metadata: ConvoKitMeta({'movie_idx': 'm109', 'movie_name': 'juno', 'release_year': '2007', 'rating': '7.90', 'votes': '152436', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L329558
# Metadata: ConvoKitMeta({'movie_idx': 'm109', 'movie_name': 'juno', 'release_year': '2007', 'rating': '7.90', 'votes': '152436', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 6
#
# Conversation ID: L329549
# Metadata: ConvoKitMeta({'movie_idx': 'm109', 'movie_name': 'juno', 'release_year': '2007', 'rating': '7.90', 'votes': '152436', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L329539
# Metadata: ConvoKitMeta({'movie_idx': 'm109', 'movie_name': 'juno', 'release_year': '2007', 'rating': '7.90', 'votes': '152436', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L329537
# Metadata: ConvoKitMeta({'movie_idx': 'm109', 'movie_name': 'juno', 'release_year': '2007', 'rating': '7.90', 'votes': '152436', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L329533
# Metadata: ConvoKitMeta({'movie_idx': 'm109', 'movie_name': 'juno', 'release_year': '2007', 'rating': '7.90', 'votes': '152436', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L329437
# Metadata: ConvoKitMeta({'movie_idx': 'm109', 'movie_name': 'juno', 'release_year': '2007', 'rating': '7.90', 'votes': '152436', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L329432
# Metadata: ConvoKitMeta({'movie_idx': 'm109', 'movie_name': 'juno', 'release_year': '2007', 'rating': '7.90', 'votes': '152436', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L330110
# Metadata: ConvoKitMeta({'movie_idx': 'm109', 'movie_name': 'juno', 'release_year': '2007', 'rating': '7.90', 'votes': '152436', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L330080
# Metadata: ConvoKitMeta({'movie_idx': 'm109', 'movie_name': 'juno', 'release_year': '2007', 'rating': '7.90', 'votes': '152436', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L330059
# Metadata: ConvoKitMeta({'movie_idx': 'm109', 'movie_name': 'juno', 'release_year': '2007', 'rating': '7.90', 'votes': '152436', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 20
#
# Conversation ID: L329576
# Metadata: ConvoKitMeta({'movie_idx': 'm109', 'movie_name': 'juno', 'release_year': '2007', 'rating': '7.90', 'votes': '152436', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L329551
# Metadata: ConvoKitMeta({'movie_idx': 'm109', 'movie_name': 'juno', 'release_year': '2007', 'rating': '7.90', 'votes': '152436', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L329522
# Metadata: ConvoKitMeta({'movie_idx': 'm109', 'movie_name': 'juno', 'release_year': '2007', 'rating': '7.90', 'votes': '152436', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L329511
# Metadata: ConvoKitMeta({'movie_idx': 'm109', 'movie_name': 'juno', 'release_year': '2007', 'rating': '7.90', 'votes': '152436', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L329505
# Metadata: ConvoKitMeta({'movie_idx': 'm109', 'movie_name': 'juno', 'release_year': '2007', 'rating': '7.90', 'votes': '152436', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L329503
# Metadata: ConvoKitMeta({'movie_idx': 'm109', 'movie_name': 'juno', 'release_year': '2007', 'rating': '7.90', 'votes': '152436', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L329499
# Metadata: ConvoKitMeta({'movie_idx': 'm109', 'movie_name': 'juno', 'release_year': '2007', 'rating': '7.90', 'votes': '152436', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L329494
# Metadata: ConvoKitMeta({'movie_idx': 'm109', 'movie_name': 'juno', 'release_year': '2007', 'rating': '7.90', 'votes': '152436', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L329490
# Metadata: ConvoKitMeta({'movie_idx': 'm109', 'movie_name': 'juno', 'release_year': '2007', 'rating': '7.90', 'votes': '152436', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L329483
# Metadata: ConvoKitMeta({'movie_idx': 'm109', 'movie_name': 'juno', 'release_year': '2007', 'rating': '7.90', 'votes': '152436', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L329414
# Metadata: ConvoKitMeta({'movie_idx': 'm109', 'movie_name': 'juno', 'release_year': '2007', 'rating': '7.90', 'votes': '152436', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L329406
# Metadata: ConvoKitMeta({'movie_idx': 'm109', 'movie_name': 'juno', 'release_year': '2007', 'rating': '7.90', 'votes': '152436', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L329317
# Metadata: ConvoKitMeta({'movie_idx': 'm109', 'movie_name': 'juno', 'release_year': '2007', 'rating': '7.90', 'votes': '152436', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L329313
# Metadata: ConvoKitMeta({'movie_idx': 'm109', 'movie_name': 'juno', 'release_year': '2007', 'rating': '7.90', 'votes': '152436', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L329311
# Metadata: ConvoKitMeta({'movie_idx': 'm109', 'movie_name': 'juno', 'release_year': '2007', 'rating': '7.90', 'votes': '152436', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L329305
# Metadata: ConvoKitMeta({'movie_idx': 'm109', 'movie_name': 'juno', 'release_year': '2007', 'rating': '7.90', 'votes': '152436', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L329925
# Metadata: ConvoKitMeta({'movie_idx': 'm109', 'movie_name': 'juno', 'release_year': '2007', 'rating': '7.90', 'votes': '152436', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 12
#
# Conversation ID: L329920
# Metadata: ConvoKitMeta({'movie_idx': 'm109', 'movie_name': 'juno', 'release_year': '2007', 'rating': '7.90', 'votes': '152436', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L329918
# Metadata: ConvoKitMeta({'movie_idx': 'm109', 'movie_name': 'juno', 'release_year': '2007', 'rating': '7.90', 'votes': '152436', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L329913
# Metadata: ConvoKitMeta({'movie_idx': 'm109', 'movie_name': 'juno', 'release_year': '2007', 'rating': '7.90', 'votes': '152436', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L329878
# Metadata: ConvoKitMeta({'movie_idx': 'm109', 'movie_name': 'juno', 'release_year': '2007', 'rating': '7.90', 'votes': '152436', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L329875
# Metadata: ConvoKitMeta({'movie_idx': 'm109', 'movie_name': 'juno', 'release_year': '2007', 'rating': '7.90', 'votes': '152436', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L329869
# Metadata: ConvoKitMeta({'movie_idx': 'm109', 'movie_name': 'juno', 'release_year': '2007', 'rating': '7.90', 'votes': '152436', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L329867
# Metadata: ConvoKitMeta({'movie_idx': 'm109', 'movie_name': 'juno', 'release_year': '2007', 'rating': '7.90', 'votes': '152436', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L329865
# Metadata: ConvoKitMeta({'movie_idx': 'm109', 'movie_name': 'juno', 'release_year': '2007', 'rating': '7.90', 'votes': '152436', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L329862
# Metadata: ConvoKitMeta({'movie_idx': 'm109', 'movie_name': 'juno', 'release_year': '2007', 'rating': '7.90', 'votes': '152436', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L329689
# Metadata: ConvoKitMeta({'movie_idx': 'm109', 'movie_name': 'juno', 'release_year': '2007', 'rating': '7.90', 'votes': '152436', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L329680
# Metadata: ConvoKitMeta({'movie_idx': 'm109', 'movie_name': 'juno', 'release_year': '2007', 'rating': '7.90', 'votes': '152436', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L329674
# Metadata: ConvoKitMeta({'movie_idx': 'm109', 'movie_name': 'juno', 'release_year': '2007', 'rating': '7.90', 'votes': '152436', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L329486
# Metadata: ConvoKitMeta({'movie_idx': 'm109', 'movie_name': 'juno', 'release_year': '2007', 'rating': '7.90', 'votes': '152436', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L329458
# Metadata: ConvoKitMeta({'movie_idx': 'm109', 'movie_name': 'juno', 'release_year': '2007', 'rating': '7.90', 'votes': '152436', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 9
#
# Conversation ID: L329456
# Metadata: ConvoKitMeta({'movie_idx': 'm109', 'movie_name': 'juno', 'release_year': '2007', 'rating': '7.90', 'votes': '152436', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L329452
# Metadata: ConvoKitMeta({'movie_idx': 'm109', 'movie_name': 'juno', 'release_year': '2007', 'rating': '7.90', 'votes': '152436', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L329442
# Metadata: ConvoKitMeta({'movie_idx': 'm109', 'movie_name': 'juno', 'release_year': '2007', 'rating': '7.90', 'votes': '152436', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 10
#
# Conversation ID: L329346
# Metadata: ConvoKitMeta({'movie_idx': 'm109', 'movie_name': 'juno', 'release_year': '2007', 'rating': '7.90', 'votes': '152436', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L329344
# Metadata: ConvoKitMeta({'movie_idx': 'm109', 'movie_name': 'juno', 'release_year': '2007', 'rating': '7.90', 'votes': '152436', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L329340
# Metadata: ConvoKitMeta({'movie_idx': 'm109', 'movie_name': 'juno', 'release_year': '2007', 'rating': '7.90', 'votes': '152436', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L329338
# Metadata: ConvoKitMeta({'movie_idx': 'm109', 'movie_name': 'juno', 'release_year': '2007', 'rating': '7.90', 'votes': '152436', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L329320
# Metadata: ConvoKitMeta({'movie_idx': 'm109', 'movie_name': 'juno', 'release_year': '2007', 'rating': '7.90', 'votes': '152436', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 18
#
# Conversation ID: L329622
# Metadata: ConvoKitMeta({'movie_idx': 'm109', 'movie_name': 'juno', 'release_year': '2007', 'rating': '7.90', 'votes': '152436', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L329581
# Metadata: ConvoKitMeta({'movie_idx': 'm109', 'movie_name': 'juno', 'release_year': '2007', 'rating': '7.90', 'votes': '152436', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L329535
# Metadata: ConvoKitMeta({'movie_idx': 'm109', 'movie_name': 'juno', 'release_year': '2007', 'rating': '7.90', 'votes': '152436', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L330047
# Metadata: ConvoKitMeta({'movie_idx': 'm109', 'movie_name': 'juno', 'release_year': '2007', 'rating': '7.90', 'votes': '152436', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 7
#
# Conversation ID: L330045
# Metadata: ConvoKitMeta({'movie_idx': 'm109', 'movie_name': 'juno', 'release_year': '2007', 'rating': '7.90', 'votes': '152436', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L330039
# Metadata: ConvoKitMeta({'movie_idx': 'm109', 'movie_name': 'juno', 'release_year': '2007', 'rating': '7.90', 'votes': '152436', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L330033
# Metadata: ConvoKitMeta({'movie_idx': 'm109', 'movie_name': 'juno', 'release_year': '2007', 'rating': '7.90', 'votes': '152436', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L330029
# Metadata: ConvoKitMeta({'movie_idx': 'm109', 'movie_name': 'juno', 'release_year': '2007', 'rating': '7.90', 'votes': '152436', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L330024
# Metadata: ConvoKitMeta({'movie_idx': 'm109', 'movie_name': 'juno', 'release_year': '2007', 'rating': '7.90', 'votes': '152436', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L330022
# Metadata: ConvoKitMeta({'movie_idx': 'm109', 'movie_name': 'juno', 'release_year': '2007', 'rating': '7.90', 'votes': '152436', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L329859
# Metadata: ConvoKitMeta({'movie_idx': 'm109', 'movie_name': 'juno', 'release_year': '2007', 'rating': '7.90', 'votes': '152436', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L329848
# Metadata: ConvoKitMeta({'movie_idx': 'm109', 'movie_name': 'juno', 'release_year': '2007', 'rating': '7.90', 'votes': '152436', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 11
#
# Conversation ID: L329632
# Metadata: ConvoKitMeta({'movie_idx': 'm109', 'movie_name': 'juno', 'release_year': '2007', 'rating': '7.90', 'votes': '152436', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L329578
# Metadata: ConvoKitMeta({'movie_idx': 'm109', 'movie_name': 'juno', 'release_year': '2007', 'rating': '7.90', 'votes': '152436', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L329574
# Metadata: ConvoKitMeta({'movie_idx': 'm109', 'movie_name': 'juno', 'release_year': '2007', 'rating': '7.90', 'votes': '152436', 'genre': "['comedy', 'drama']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L334178
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L334176
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L333904
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L333811
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L334151
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L334145
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L333966
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 6
#
# Conversation ID: L333941
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L333937
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L333935
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L333930
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L333928
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L333917
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L333912
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L333889
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L333878
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L333876
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L333871
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L333777
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L333747
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L333742
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L333740
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L333728
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L333725
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L334211
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L334207
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L334184
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L334166
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L334098
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L334096
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L334062
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L333824
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L333783
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L333719
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L333711
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L333708
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L333696
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L333694
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L333689
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L333685
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L333598
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L333596
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L334081
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L334079
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L334073
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L334064
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L334219
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L334131
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L334129
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L334121
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L334115
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L334108
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L333979
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L333921
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 6
#
# Conversation ID: L333900
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L333891
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 9
#
# Conversation ID: L333882
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L333869
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L333861
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 7
#
# Conversation ID: L333772
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L333751
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L333738
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L333733
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L333731
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L334216
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L334213
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L334192
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L334172
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L334042
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L334037
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L334033
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L334028
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L334017
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L333997
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L333991
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L333988
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L333858
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L333830
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L333819
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L333817
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L333803
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L333717
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L333704
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L333700
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L333698
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L333664
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L333657
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 7
#
# Conversation ID: L333655
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L333652
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L333623
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 7
#
# Conversation ID: L333604
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L333602
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L333600
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L333587
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L333579
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L333571
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L333568
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L333563
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L334238
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L334235
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L334231
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L334170
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L334093
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L334069
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L334026
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L334011
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L334005
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L334003
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L333855
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L333844
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L333646
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L333640
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L333636
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L333765
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L333762
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L333754
# Metadata: ConvoKitMeta({'movie_idx': 'm110', 'movie_name': 'kalifornia', 'release_year': '1993', 'rating': '6.70', 'votes': '21830', 'genre': "['crime', 'drama', 'thriller']"})
# Number of utterances in conversation: 8
#
# Conversation ID: L334582
# Metadata: ConvoKitMeta({'movie_idx': 'm111', 'movie_name': 'kids', 'release_year': '1995', 'rating': '6.80', 'votes': '26546', 'genre': "['crime', 'drama']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L334564
# Metadata: ConvoKitMeta({'movie_idx': 'm111', 'movie_name': 'kids', 'release_year': '1995', 'rating': '6.80', 'votes': '26546', 'genre': "['crime', 'drama']"})
# Number of utterances in conversation: 6
#
# Conversation ID: L334554
# Metadata: ConvoKitMeta({'movie_idx': 'm111', 'movie_name': 'kids', 'release_year': '1995', 'rating': '6.80', 'votes': '26546', 'genre': "['crime', 'drama']"})
# Number of utterances in conversation: 6
#
# ...
# Number of utterances in conversation: 6
#
# Conversation ID: L666019
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L665957
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665904
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665896
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L665891
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L665873
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665868
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L665865
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L665861
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665840
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665802
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L665798
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665775
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L665755
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L665748
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L665691
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L665676
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665663
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L665658
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665636
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L665627
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 7
#
# Conversation ID: L665623
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L665615
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 8
#
# Conversation ID: L665564
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665558
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665552
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665548
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666168
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666166
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666160
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666158
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666151
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 6
#
# Conversation ID: L666149
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665949
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L665900
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665885
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665694
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L665651
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665994
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L665992
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665987
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L666462
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666365
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L666361
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L666503
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L666388
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 11
#
# Conversation ID: L666487
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666483
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666480
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L666357
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666249
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666246
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L666546
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666485
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666460
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666383
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L666251
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666497
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 6
#
# Conversation ID: L666575
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666324
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L666262
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L666520
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L666369
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L666256
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 2

# %%
#Create empty lists to store data
conversation_ids = []
movie_indices = []
movie_names = []
release_years = []
ratings = []
votes = []
genres = []
num_utterances = []

# Loop through conversations and extract data
for convo_id in corpus.get_conversation_ids():
    convo = corpus.get_conversation(convo_id)

    # Extract metadata from ConvoKitMeta object
    metadata = convo.meta

    # Append data to respective lists
    conversation_ids.append(convo_id)
    movie_indices.append(metadata['movie_idx'])
    movie_names.append(metadata['movie_name'])
    release_years.append(metadata['release_year'])
    ratings.append(metadata['rating'])
    votes.append(metadata['votes'])
    genres.append(metadata['genre'])
    num_utterances.append(len(convo.get_utterance_ids()))

# Create a DataFrame from the lists
data = {
    'Conversation ID': conversation_ids,
    'Movie Index': movie_indices,
    'Movie Name': movie_names,
    'Rating': ratings,
}

df = pd.DataFrame(data)
df
# Out:
#       Conversation ID Movie Index                  Movie Name Rating
# 0               L1044          m0  10 things i hate about you   6.90
# 1                L984          m0  10 things i hate about you   6.90
# 2                L924          m0  10 things i hate about you   6.90
# 3                L870          m0  10 things i hate about you   6.90
# 4                L866          m0  10 things i hate about you   6.90
# ...               ...         ...                         ...    ...
# 83092         L666324        m616                   zulu dawn   6.40
# 83093         L666262        m616                   zulu dawn   6.40
# 83094         L666520        m616                   zulu dawn   6.40
# 83095         L666369        m616                   zulu dawn   6.40
# 83096         L666256        m616                   zulu dawn   6.40
#
# [83097 rows x 4 columns]

# %%
#rating scale
reader = Reader(rating_scale=(1, 10))

# %%
# Load the dataset into Surprise format
data = df[['Conversation ID','Movie Name','Rating']]
data = Dataset.load_from_df(data, reader)

# Split the data into training and testing sets (80% train, 20% test)
trainset, testset = train_test_split(data, test_size=0.2, random_state=42)

# Create and train the SVD recommendation model
model = SVD()
model.fit(trainset)

# Evaluate the model on the testing data (calculate RMSE)
predictions = model.test(testset)
rmse = accuracy.rmse(predictions)
# Out:
# RMSE: 0.0640

# %%
# Generate recommendations for a specific user
user_id = 'L36547'
user_movies = df[df['Conversation ID'] == user_id]['Movie Name'].unique()

# Create a list of unrated movies for the user
all_movies = df['Movie Name'].unique()
unrated_movies = np.setdiff1d(all_movies, user_movies)

# Generate predictions for unrated movies
user_recommendations = []
for movie_id in unrated_movies:
    predicted_rating = model.predict(user_id, movie_id).est
    user_recommendations.append((movie_id, predicted_rating))

# Sort recommendations by predicted rating (highest first)
user_recommendations.sort(key=lambda x: x[1], reverse=True)

# %%
# Display the top n recommendations
top_n = 3
print(f'Top {top_n} recommendations for user {user_id}:')
for movie_id, predicted_rating in user_recommendations[:top_n]:
    print(f'Movie ID: {movie_id}, Predicted Rating: {predicted_rating:.2f}')
# Out:
# Top 3 recommendations for user L36547:
# Movie ID: neuromancer, Predicted Rating: 9.29
# Movie ID: the godfather, Predicted Rating: 9.12
# Movie ID: the godfather: part ii, Predicted Rating: 8.92
